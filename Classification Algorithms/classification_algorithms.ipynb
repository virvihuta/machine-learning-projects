# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("500hits.csv", encoding='latin-1')

# %%
df.head()
# Out:
#          PLAYER  YRS     G     AB     R     H   2B   3B   HR   RBI    BB  \
# 0       Ty Cobb   24  3035  11434  2246  4189  724  295  117   726  1249
# 1   Stan Musial   22  3026  10972  1949  3630  725  177  475  1951  1599
# 2  Tris Speaker   22  2789  10195  1882  3514  792  222  117   724  1381
# 3   Derek Jeter   20  2747  11195  1923  3465  544   66  260  1311  1082
# 4  Honus Wagner   21  2792  10430  1736  3430  640  252  101     0   963
#
#      SO   SB   CS     BA  HOF
# 0   357  892  178  0.366    1
# 1   696   78   31  0.331    1
# 2   220  432  129  0.345    1
# 3  1840  358   97  0.310    1
# 4   327  722   15  0.329    1

# %%
X = df.drop(columns=['PLAYER','HOF'])

# %%
y = df['HOF']

# %%
X.head()
# Out:
#    YRS     G     AB     R     H   2B   3B   HR   RBI    BB    SO   SB   CS  \
# 0   24  3035  11434  2246  4189  724  295  117   726  1249   357  892  178
# 1   22  3026  10972  1949  3630  725  177  475  1951  1599   696   78   31
# 2   22  2789  10195  1882  3514  792  222  117   724  1381   220  432  129
# 3   20  2747  11195  1923  3465  544   66  260  1311  1082  1840  358   97
# 4   21  2792  10430  1736  3430  640  252  101     0   963   327  722   15
#
#       BA
# 0  0.366
# 1  0.331
# 2  0.345
# 3  0.310
# 4  0.329

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: HOF, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=11,test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)

# %%
print(X_train_scaled)
# Out:
# [[ 0.37205061 -0.05280385 -0.17535635 ... -0.95463009 -0.42607211
#   -0.76823723]
#  [-1.5084226  -0.6001859  -0.53825069 ...  0.27017176  0.99507785
#    0.13478967]
#  [-1.13232796 -0.70567098 -0.88653699 ... -0.86290484 -0.16214426
#    0.08726194]
#  ...
#  [ 0.37205061 -0.22671169 -0.1253815  ...  0.38347942  0.67024357
#    1.60814935]
#  [ 0.74814526  1.25863231  0.92024625 ...  0.66944637  1.01537999
#   -1.05340363]
#  [-1.13232796 -0.85392029 -1.02569774 ... -0.86290484 -0.66969781
#   -0.34048765]]

# %%
print(X_test_scaled)
# Out:
# [[ 0.25365979 -0.47302701 -1.13223008 ... -0.98067235 -0.46058275
#   -0.27255712]
#  [ 0.25365979 -0.02566495 -0.25741356 ... -0.79997787 -0.17675594
#   -0.41106975]
#  [-0.70270618 -0.00657023  0.64680187 ...  1.10333735  1.71542277
#    2.45152469]
#  ...
#  [-0.06512887 -0.56031716 -0.92246481 ... -0.926464   -0.98093189
#   -0.08787361]
#  [-0.38391752  0.08617557  0.61343013 ... -0.80600102 -0.48423498
#    0.51234781]
#  [ 0.57244845  0.96180496  1.31344225 ...  0.07940195 -0.12945147
#    1.38959449]]

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn_model = KNeighborsClassifier()

# %%
knn_model.fit(X_train_scaled, y_train)
# Out:
# KNeighborsClassifier()

# %%
accuracy = knn_model.score(X_test_scaled, y_test)
print("Accuracy: ", accuracy)
# Out:
# Accuracy:  0.8709677419354839

# %%
y_pred_knn = knn_model.predict(X_test_scaled)

# %%
from sklearn.metrics import classification_report

# %%
score_knn = classification_report(y_test, y_pred_knn)
print(score_knn)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.93      0.91        67
#            1       0.79      0.73      0.76        26
#
#     accuracy                           0.87        93
#    macro avg       0.85      0.83      0.84        93
# weighted avg       0.87      0.87      0.87        93

# %%
from sklearn.svm import SVC

# %%
svm_model = SVC()

# %%
svm_model.fit(X_train_scaled,y_train)
# Out:
# SVC()

# %%
y_pred_svm = svm_model.predict(X_test_scaled)

# %%
score_svm = classification_report(y_test, y_pred_svm)

# %%
print(score_svm)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.95        67
#            1       0.95      0.77      0.85        26
#
#     accuracy                           0.92        93
#    macro avg       0.93      0.88      0.90        93
# weighted avg       0.93      0.92      0.92        93

# %%
from sklearn.naive_bayes import GaussianNB

# %%
nb_model = GaussianNB()

# %%
nb_model.fit(X_train_scaled, y_train)
# Out:
# GaussianNB()

# %%
y_pred_nb = nb_model.predict(X_test_scaled)

# %%
score_nb = classification_report(y_test, y_pred_nb)

# %%
print(score_nb)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.94      0.92        67
#            1       0.83      0.73      0.78        26
#
#     accuracy                           0.88        93
#    macro avg       0.86      0.84      0.85        93
# weighted avg       0.88      0.88      0.88        93

# %%
from sklearn.linear_model import LogisticRegression

# %%
lg_model = LogisticRegression()

# %%
lg_model.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression()

# %%
y_pred_lg = lg_model.predict(X_test_scaled)

# %%
score_lg = classification_report(y_test, y_pred_lg)

# %%
print(score_lg)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.94      0.92        67
#            1       0.83      0.73      0.78        26
#
#     accuracy                           0.88        93
#    macro avg       0.86      0.84      0.85        93
# weighted avg       0.88      0.88      0.88        93

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
tree_model = DecisionTreeClassifier()

# %%
tree_model.fit(X_train_scaled, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred_tree = tree_model.predict(X_test_scaled)

# %%
score_tree = classification_report(y_test, y_pred_tree)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
print(score_tree)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.75      0.81        67
#            1       0.53      0.73      0.61        26
#            2       0.00      0.00      0.00         0
#
#     accuracy                           0.74        93
#    macro avg       0.47      0.49      0.48        93
# weighted avg       0.79      0.74      0.76        93

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
RFC_model = RandomForestClassifier()

# %%
RFC_model.fit(X_train_scaled, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred_RFC = RFC_model.predict(X_test_scaled)

# %%
score_RFC = classification_report(y_test, y_pred_RFC)

# %%
print(score_RFC)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.93      0.93        67
#            1       0.81      0.85      0.83        26
#
#     accuracy                           0.90        93
#    macro avg       0.88      0.89      0.88        93
# weighted avg       0.90      0.90      0.90        93

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
model_GBC = GradientBoostingClassifier()

# %%
model_GBC.fit(X_train_scaled, y_train)
# Out:
# GradientBoostingClassifier()

# %%
y_pred_GBC = model_GBC.predict(X_test_scaled)

# %%
score_GBC = classification_report(y_test, y_pred_GBC)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
print(score_GBC)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.90      0.90        67
#            1       0.72      0.69      0.71        26
#            2       0.00      0.00      0.00         0
#
#     accuracy                           0.84        93
#    macro avg       0.54      0.53      0.54        93
# weighted avg       0.86      0.84      0.85        93
